# %% [markdown]
# # How to consume Amazon Bedrock models like Amazon Nova, Anthropic Claude and Amazon Titan Models via SAP GenAI hub
# ## Setup AI Core credentials
#
# All notebooks in this repo invoke the AI Core REST APIs to send your payloads into LLMs hosted on SAP GenAI hub. The documentation for the APIs are provided [here](https://api.sap.com/api/AI_CORE_API/resource/Deployment) and [here](https://help.sap.com/docs/sap-ai-core/sap-ai-core-service-guide/consume-generative-ai-models-using-sap-ai-core#aws-bedrock)

# %% [markdown]
# Start by creating a service key from your AI Core environment [here](https://help.sap.com/docs/sap-ai-core/sap-ai-core-service-guide/create-service-key).
#
# Before using it we need to bring it in the correct form. To do so run this command.
#
# Note: If you are doing this as part of an AWS Hosted Event please follow the instructions under Work Environment Setup. It will lead you to download the service key in the correct form and after following the Work Environment Set Up you can continue with Notebook 01.

# %%
# skip this step if you are at an AWS hosted event 
# add the path to your service key and run this cell
# example: !python3 util/transform_config.py ./config.json
# !python3 ./util/transform_config.py <path-to-your-service-key-file>

# %% [markdown]
# In the next step you need to confirm the file which should now have the following structure:
#
# ```sh
# {
#   "AICORE_AUTH_URL": "<>.authentication.us10.hana.ondemand.com",
#   "AICORE_CLIENT_ID": "sb-b...64",
#   "AICORE_CLIENT_SECRET": "21...xc=",
#   "AICORE_RESOURCE_GROUP": "default",
#   "AICORE_BASE_URL": "https://api.ai.prod.<>.ondemand.com"
# }
# ```
# And move it to ~/.aicore/config.json by running the next cell:

# %%
# moving config.json to .aicore directory 
# !mkdir -p ~/.aicore && mv config.json ~/.aicore/config.json

# %% [markdown]
# You can now verify the configuration was correctly created by running the next cell:

# %%
# !cat ~/.aicore/config.json

# %% [markdown]
# Please install all the dependencies of the project now.

# %%
# !pip install .

# %% [markdown]
# Now you are all setup to proceed with the rest of the notebooks!
